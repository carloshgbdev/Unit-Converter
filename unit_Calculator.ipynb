# %%
from IPython.display import clear_output

# Simple converter functions
Converter = lambda unit_value, formule: unit_value * formule

def Temperature_Converter(start, end, value):
  match start, end:
        case 1, 1:
          return value
        case 1, 2:
          return (value - 32)*5/9
        case 1, 3:
          return (value - 32)*5/9 + 273.15
        case 2, 1:
          return value*9/5 + 32
        case 2, 2:
          return value
        case 2, 3:
          return value + 273.15
        case 3, 1:
          return (value - 273.15)*9/5 + 32
        case 3, 2:
          return value - 273.15
        case 3, 3:
          return value

def Distance_Converter(start, end, convertion):
  match start:
    case 1:
      convertion = convertion * 9.461e15
    case 2:
      convertion = convertion * 1609
    case 3:
      convertion = convertion * 1000
    case 4:
      pass
    case 5:
      convertion = convertion / 3.281
    case 6:
      convertion = convertion / 39.37
    case 7:
      convertion = convertion / 10 ** 2
    case 8:
      convertion = convertion / 10 ** 3
    case 9:
      convertion = convertion / 10 ** 6
    case 10:
      convertion = convertion / 10 ** 9
    case 11:
      convertion = convertion / 10 ** 12
    
  match end:
    case 1:
      convertion = convertion / 9.461e15
    case 2:
      convertion = convertion / 1609
    case 3:
      convertion = convertion / 1000
    case 4:
      pass
    case 5:
      convertion = convertion * 3.281
    case 6:
      convertion = convertion * 39.37
    case 7:
      convertion = convertion * 10 ** 2
    case 8:
      convertion = convertion * 10 ** 3
    case 9:
      convertion = convertion * 10 ** 6
    case 10:
      convertion = convertion * 10 ** 9
    case 11:
      convertion = convertion * 10 ** 12
  
  return convertion

def Time_Converter(start, end, convertion):
  match start:
    case 1:
      convertion = convertion * 10 * 12 * 4 * 7 * 24 * 60 * 60
    case 2:
      convertion = convertion * 12 * 4 * 7 * 24 * 60 * 60
    case 3:
      convertion = convertion * 4 * 7 * 24 * 60 * 60
    case 4:
      convertion = convertion * 7 * 24 * 60 * 60
    case 5:
      convertion = convertion * 24 * 60 * 60
    case 6:
      convertion = convertion * 60 * 60
    case 7:
      convertion = convertion * 60
    case 8:
      pass
    case 9:
      convertion = convertion / 10 ** 3
    case 10:
      convertion = convertion / 10 ** 6
    case 11:
      convertion = convertion / 10 ** 9
    case 12:
      convertion = convertion / 10 ** 12

  match end:
    case 1:
      convertion = convertion / 10 / 12 / 4 / 7 / 24 / 60 / 60
    case 2:
      convertion = convertion / 12 / 4 / 7 / 24 / 60 / 60
    case 3:
      convertion = convertion / 4 / 7 / 24 / 60 / 60
    case 4:
      convertion = convertion / 7 / 24 / 60 / 60
    case 5:
      convertion = convertion / 24 / 60 / 60
    case 6:
      convertion = convertion / 60 / 60
    case 7:
      convertion = convertion / 60
    case 8:
      pass
    case 9:
      convertion = convertion * 10 ** 3
    case 10:
      convertion = convertion * 10 ** 6
    case 11:
      convertion = convertion * 10 ** 9
    case 12:
      convertion = convertion * 10 ** 12
    
  return convertion

def Mass_Converter(start, end, convertion):
  match start_unit:
    case 1:
      convertion = convertion * 10 ** 6
    case 2:
      convertion = convertion * 10 ** 3
    case 3:
      pass
    case 4:
      convertion = convertion / 10 ** 3
    case 5:
      convertion = convertion / 10 ** 6
    case 6:
      convertion = convertion / 10 ** 9
    case 7:
      convertion = convertion / 10 ** 12

  match end_unit:
    case 1:
      convertion = convertion / 10 ** 6
    case 2:
      convertion = convertion / 10 ** 3
    case 3:
      pass
    case 4:
      convertion = convertion * 10 ** 3
    case 5:
      convertion = convertion * 10 ** 6
    case 6:
      convertion = convertion * 10 ** 9
    case 7:
      convertion = convertion * 10 ** 12
  
  return convertion

while True:
  print('-'*70 + "\nChoose which type of units you want to work with:\n")
  print("[1] - Distance units.")
  print("[2] - Time units.")
  print("[3] - Mass units.")
  print("[4] - Temperature units.")
  print("\n[0] - Exit.\n")

  operation = int(input("> "))

  match operation:
    case 1:
      clear_output()
      distance_units = ["Light-Years", "Miles", "Kilometers", "Meters", 
                        "Feets", "Inches", "Centimeters", "Milimeters",
                        "Micrometers", "Picometers"]

      print('-'*70 + "\nChoose the start unit for distance:\n")
      for unit in distance_units:
        print(f"[{distance_units.index(unit) + 1}] - {unit}.")

      print()
      start_unit = int(input("> "))
      
      clear_output()
      print('-'*70 + "\nChoose the final unit for distance:\n")
      for unit in distance_units:
        print(f"[{distance_units.index(unit) + 1}] - {unit}.")

      print()
      end_unit = int(input("> "))

      clear_output()
      value = float(input('-'*70 + "\nEnter the value of the start unit: "))
      convertion = Distance_Converter(start_unit, end_unit, 1)
      end_value = Converter(value, convertion)

      print(f"\n{distance_units[start_unit - 1]} to {distance_units[end_unit - 1]}", end = ' -> ')
      print(f"{end_value:.2f} {distance_units[end_unit - 1].lower()}.")

      input("\nPress enter to return to the menu.")
      clear_output()

    case 2:
      clear_output()
      time_units = ["Decades", "Years", "Months", "Weeks", "Days", "Hours",
                    "Minutes", "Seconds", "Miliseconds", "Microseconds", 
                    "Nanoseconds", "Picoseconds"]

      print('-'*70 + "\nChoose the start unit for time:\n")
      for unit in time_units:
        print(f"[{time_units.index(unit) + 1}] - {unit}.")

      print()
      start_unit = int(input("> "))
      
      clear_output()
      print('-'*70 + "\nChoose the final unit for time:\n")
      for unit in time_units:
        print(f"[{time_units.index(unit) + 1}] - {unit}.")

      print()
      end_unit = int(input("> "))

      clear_output()
      value = float(input('-'*70 + "\nEnter the value of the start unit: "))
      convertion = Time_Converter(start_unit, end_unit, 1)
      end_value = Converter(value, convertion)

      print(f"\n{time_units[start_unit - 1]} to {time_units[end_unit - 1]}", end = ' -> ')
      print(f"{end_value:.2f} {time_units[end_unit - 1].lower()}.")

      input("\nPress enter to return to the menu.")
      clear_output()

    case 3:
      clear_output()
      mass_units = ["Tons", "Kilograms", "Grams", "Miligrams",
                    "Micrograms", "Nanograms", "Picograms"]

      print('-'*70 + "\nChoose the start unit for mass:\n")
      for unit in mass_units:
        print(f"[{mass_units.index(unit) + 1}] - {unit}.")

      print()
      start_unit = int(input("> "))
      
      clear_output()
      print('-'*70 + "\nChoose the final unit for mass:\n")
      for unit in mass_units:
        print(f"[{mass_units.index(unit) + 1}] - {unit}.")

      print()
      end_unit = int(input("> "))

      clear_output()
      value = float(input('-'*70 + "\nEnter the value of the start unit: "))
      convertion = Mass_Converter(start_unit, end_unit, 1)
      end_value = Converter(value, convertion)

      print(f"\n{mass_units[start_unit - 1]} to {mass_units[end_unit - 1]}", end = ' -> ')
      print(f"{end_value:.2f} {mass_units[end_unit - 1].lower()}.")

      input("\nPress enter to return to the menu.")
      clear_output()
    case 4:
      clear_output()
      temperature_units = ["Fahrenheits", "Celsius", "Kelvins"]

      print('-'*70 + "\nChoose the start unit for temperature:\n")
      for unit in temperature_units:
        print(f"[{temperature_units.index(unit) + 1}] - {unit}.")

      print()
      start_unit = int(input("> "))
      
      clear_output()
      print('-'*70 + "\nChoose the final unit for temperature:\n")
      for unit in temperature_units:
        print(f"[{temperature_units.index(unit) + 1}] - {unit}.")

      print()
      end_unit = int(input("> "))

      clear_output()
      value = float(input('-'*70 + "\nEnter the value of the start unit: "))
      end_value = Temperature_Converter(start_unit, end_unit, value)

      print(f"\n{temperature_units[start_unit - 1]} to {temperature_units[end_unit - 1]}", end = ' -> ')
      print(f"{end_value:.2f} {temperature_units[end_unit - 1].lower()}.")

      input("\nPress enter to return to the menu.")
      clear_output()
    case 0:
      break
# Out:
# ----------------------------------------------------------------------
# Choose which type of units you want to work with:
#
# [1] - Distance units.
# [2] - Time units.
# [3] - Mass units.
# [4] - Temperature units.
#
# [0] - Exit.
#
# > 0
